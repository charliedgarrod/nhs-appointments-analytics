# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the cleaned data files
apps = pd.read_excel("../data/clean/apps_clean.xlsx")
cats = pd.read_excel("../data/clean/cat_clean.xlsx")
dur = pd.read_csv("../data/clean/dur_clean.csv")
reg = pd.read_csv("../data/clean/reg_clean.csv")
tweet = pd.read_csv("../data/clean/tweet_clean.csv")
